# %%
from tensorflow.keras.datasets import mnist #from keras datasets 匯入mnist data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data() #取得mnist datase and package to tuple

# %%
#build NN structure
from tensorflow import keras
from tensorflow.keras import layers

model=keras.Sequential([
    layers.Dense(512,activation="relu"),
    layers.Dense(10,activation="softmax")
])

# %%
model.compile(optimizer="rmsprop",
       loss="sparse_categorical_crossentropy",
       metrics=["acc"])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 6s 11ms/step - loss: 0.2643 - acc: 0.9242
# Epoch 2/5
# 469/469 [==============================] - 6s 13ms/step - loss: 0.1064 - acc: 0.9688
# Epoch 3/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0698 - acc: 0.9790
# Epoch 4/5
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0511 - acc: 0.9853
# Epoch 5/5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0382 - acc: 0.9888

# %%
test_digits=test_images[0:10]
pred=model.predict(test_digits)
pred[0] #check pred array the first element
# Out:
# 1/1 [==============================] - 0s 131ms/step
# array([3.0701724e-08, 1.0176007e-08, 7.4389745e-06, 1.9939422e-05,
#        1.4041120e-10, 9.0685823e-08, 1.4975729e-12, 9.9997073e-01,
#        1.5775802e-07, 1.5693370e-06], dtype=float32)

# %%
train_loss,train_acc=model.evaluate(train_images,train_labels)
print('train_acc:',train_acc)

test_loss,test_acc=model.evaluate(test_images,test_labels)
print('test_acc:',test_acc)
# Out:
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0252 - acc: 0.9929
# train_acc: 0.9929333329200745
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0630 - acc: 0.9821
# test_acc: 0.9821000099182129
